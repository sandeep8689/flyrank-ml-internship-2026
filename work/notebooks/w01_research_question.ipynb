# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeep8689/flyrank-ml-internship-2026/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sandeep8689/flyrank-ml-internship-2026/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# # My Lane
#
# I selected the Content Refresh lane.
#
# The goal of this lane is to identify existing content that should be updated to improve its search performance. Many web pages lose traffic over time because search trends, competition, and user behavior change. By analyzing search and engagement data, machine learning can help identify which content should be refreshed first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# # Research Question
#
# **Question:**
# Which content items should be refreshed to improve search visibility and user engagement?
#
# **Decision:**
# Decide whether a content page should be refreshed.
#
# **Action:**
# SEO teams update the content, improve keywords, and optimize the page.
#
# **Cost of a wrong recommendation:**
# Refreshing a page that does not need updates wastes time and resources. Missing an outdated page may reduce traffic, user engagement, and search rankings.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !git clone https://github.com/sandeep8689/flyrank-ml-internship-2026.git
# Out:
# Cloning into 'flyrank-ml-internship-2026'...
# remote: Enumerating objects: 141, done.
# remote: Counting objects: 100% (141/141), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 141 (delta 54), reused 113 (delta 40), pack-reused 0 (from 0)
# Receiving objects: 100% (141/141), 1.82 MiB | 10.48 MiB/s, done.
# Resolving deltas: 100% (54/54), done.

# %%
# %cd /content/flyrank-ml-internship-2026
# Out:
# /content/flyrank-ml-internship-2026

# %%
import os

for root, dirs, files in os.walk("data"):
    for file in files:
        print(os.path.join(root, file))
# Out:
# data/raw/content_refresh_anonymized.csv

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Number of rows:", len(df))
print("Number of columns:", len(df.columns))

print("\nAverage CTR:")
print(df["ctr"].mean())

print("\nAverage Search Volume:")
print(df["search_volume"].mean())

df.head()
# Out:
# Number of rows: 30000
# Number of columns: 44
#
# Average CTR:
# 0.5107333333333334
#
# Average Search Volume:
# 158.88239139909922
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# ...

# %% [markdown]
# # Quick Look at the Data
#
# The dataset contains **30,000 rows** and **44 columns**.
#
# The average CTR (Click-Through Rate) is **0.5107**.
#
# The average search volume is **158.88**.
#
# These values show that the dataset contains a large amount of search and SEO performance information. This makes it suitable for analyzing which content should be refreshed to improve search performance and user engagement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# # Careful Words
#
# This analysis does not prove that refreshing content will always improve search performance.
#
# The model will only identify patterns from historical data. Final decisions should still consider business goals and expert review before updating content.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# # Self Check
#
# - ✅ Selected the Content Refresh lane.
# - ✅ Defined the research question.
# - ✅ Explained the decision and action.
# - ✅ Explained the cost of an incorrect prediction.
# - ✅ Explored the dataset with real numbers.
# - ✅ Used careful language about what the analysis can and cannot claim.
